# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np


from sklearn import cluster
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %% [markdown]
# ## Part One: Data overview

# %% [markdown]
# For your own exploratory analysis we propose to work with Moscow Khrushchevki - panel 5 floor buildings. For that we prepared several datasets:
#
# - Khrushchevki over Moscow from https://www.reformagkh.ru/
# - Moscow boundaries
# - Additional open data

# %%
buildings = gpd.read_file('Khrushchevki_data_cut_moscow.geojson')

# %%
buildings.head()
# Out:
#      area  area_land  area_live  area_nonlive  area_parking  \
# 0  4688.1        0.0     3722.9        965.20           0.0
# 1  1882.6        0.0     1882.6          0.00           0.0
# 2  4480.6        0.0     4333.0        147.60           0.0
# 3  4018.8        0.0     4018.8          0.00           0.0
# 4  3395.4        0.0     3395.4        826.76           0.0
#
#    critical_conditions                     geometry  house_id  \
# 0                  0.0   POINT (37.52377 55.818372)   7840091
# 1                  0.0  POINT (37.524758 55.818437)   7840108
# 2                  0.0  POINT (37.526214 55.818488)   7840136
# 3                  0.0  POINT (37.524875 55.818923)   7840164
# 4                  0.0  POINT (37.524722 55.821006)   7840200
#
#         house_type id   ...    playground  room_nonresidential_count  \
# 0  apartment house  0   ...           0.0                        0.0
# 1  apartment house  1   ...           0.0                        0.0
# ...

# %% [markdown]
# **area** - total building area, sq km
#
# **area_land** - total
#
# **area_live** - total residential area, sq km
#
# **area_nonlive** - total non residential area, sq km
#
# **area_parking** - area of parking close to the building, sq km
#
# **critical_conditions** - is house
#
# **geometry** - point coordinates of buildings
#
# **house_id** - building id
#
# **id** - record id
#
# **house_type** - building type
#
# **playground** - availability of a playground
#
# **room_nonresidential_count** - number of non residential rooms
#
# **room_residential_count** - number of non residential rooms
#
# **room_total_count** - total number of rooms
#
# **service_day**	- day of last building service
#
# **service_last_date** - date of last building service
#
# **service_month** - month of last building service
#
# **service_year** - year of last building service
#
# **sportground**	- availability of a sports field
#
# **year** - year of construction

# %%
buildings['levels_max'].value_counts()
# Out:
# 5    7558
# Name: levels_max, dtype: int64

# %%
buildings.house_type.value_counts()
# Out:
# apartment house                     7463
# residential house terraced house      59
# Spesialized housing stock             19
# unknown                               17
# Name: house_type, dtype: int64

# %%
buildings.critical_conditions.value_counts()
# Out:
# 0.0    7547
# 1.0      11
# Name: critical_conditions, dtype: int64

# %%
buildings.groupby('house_type')['area_live'].mean().reset_index()
# Out:
#                          house_type    area_live
# 0         Spesialized housing stock  2552.526316
# 1                   apartment house  3151.961235
# 2  residential house terraced house  2696.103390
# 3                           unknown  2757.076471

# %%
buildings.groupby('house_type')['year'].mean().reset_index()
# Out:
#                          house_type         year
# 0         Spesialized housing stock  1963.947368
# 1                   apartment house  1961.804368
# 2  residential house terraced house  1961.033898
# 3                           unknown  1962.647059

# %%
buildings.dtypes
# Out:
# area                         float64
# area_land                    float64
# area_live                    float64
# area_nonlive                 float64
# area_parking                 float64
# critical_conditions          float64
# geometry                      object
# house_id                       int64
# house_type                    object
# id                            object
# in_moscow                      int64
# levels_max                     int64
# playground                   float64
# room_nonresidential_count    float64
# room_residential_count       float64
# room_total_count             float64
# service_day                  float64
# service_last_date             object
# service_month                float64
# service_year                 float64
# sportground                  float64
# year                         float64
# dtype: object

# %%
features = ['area_live', 'area_nonlive','area_parking', 'room_total_count','service_year', 'year']
buildings[features].hist(figsize=(16,10),bins=100);

# %% [markdown]
# ### Year of construction vs Technical service year

# %%
buildings.groupby('year').size().plot(kind='line',label='construction year')
buildings.groupby('service_year').size().plot(kind='line',label='service year')

# %%
plt.scatter(buildings['year'], buildings['service_year'])
plt.xlabel('Year of construction')
plt.ylabel('Service year')

# %% [markdown]
# ### Outdoor facilites

# %%
buildings.playground.value_counts()
# Out:
# 1.0    3685
# 0.0    2955
# Name: playground, dtype: int64

# %%
buildings.sportground.value_counts()
# Out:
# 0.0    5881
# 1.0     682
# Name: sportground, dtype: int64

# %%
buildings[(buildings.playground == 1) & (buildings.sportground == 1)].shape
# Out:
# (589, 22)

# %% [markdown]
# ### Area

# %%
sns.violinplot(x='house_type',y='area_nonlive', data=buildings)
plt.ylabel('Frequency')

# %%
sns.boxplot(x='house_type',y='area_nonlive', data=buildings)
plt.ylabel('Frequency')

# %%
sns.boxplot(x='house_type',y='area_live', data=buildings)
plt.ylabel('Frequency')

# %% [markdown]
# ## Clustering

# %%
kmeans5 = cluster.KMeans(n_clusters=6)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(buildings[['area_live', 'critical_conditions', 'playground', 
                              'sportground', 'room_residential_count','service_year', 'year']].fillna(0))

# %%
k5cls = kmeans5.fit(X_scaled)

# %%
k5cls.labels_
# Out:
# array([1, 1, 1, ..., 0, 2, 0], dtype=int32)

# %%
buildings['k5cls'] = k5cls.labels_

# %%
base = districts.plot(linewidth=0.1, facecolor=None, alpha=0.01, figsize=(12,10));
base.set_axis_off()
buildings.plot(column='k5cls',ax=base, categorical=True, legend=True)

# %%
# %%time
tsne = TSNE(random_state=17,perplexity=100)
tsne_representation = tsne.fit_transform(X_scaled)
# Out:
# CPU times: user 4min 7s, sys: 1min 3s, total: 5min 11s
# Wall time: 5min 54s

# %%
tsne_representation
# Out:
# array([[-2.48704304, -3.58108028],
#        [-0.87104205, -0.18523167],
#        [-1.03260757, -3.25653991],
#        ...,
#        [-4.58528101, -4.26189893],
#        [-6.52437595, -5.36541984],
#        [-3.92056445, -0.86119646]])

# %%
plt.scatter(tsne_representation[:, 0], tsne_representation[:, 1]);

# %%
_, axes = plt.subplots(1, 2, sharey=True, figsize=(16,6))

axes[0].scatter(tsne_representation[:, 0], tsne_representation[:, 1], 
            c=buildings['playground'], cmap='spring')
axes[1].scatter(tsne_representation[:, 0], tsne_representation[:, 1], 
            c=buildings['sportground'], cmap='Blues');
axes[0].set_title('Playground');
axes[1].set_title('Sportground');

# %%
categories = {'apartment house': 'red', 'residential house terraced house': 'blue', 
 'Spesialized housing stock':'green', 'unknown': 'black'}

# %% [markdown]
# ## Moscow census data

# %%
districts = gpd.read_file('moscow_boundaries_demography.geojson')

# %%
districts.head()
# Out:
#                                   Area     District  TotalMen  TotalMen18to27  \
# 0      Zapadnyj administrativnyj okrug      Vnukovo      9174            1054
# 1      Zapadnyj administrativnyj okrug     Kuntsevo     54226            5234
# 2      Zapadnyj administrativnyj okrug   Krylatskoe     30687            2394
# 3  Tsentral'nyj administrativnyj okrug  Meschanskij     25658            1937
# 4    Vostochnyj administrativnyj okrug   Sokol'niki     20302            1897
#
#    TotalMen18to60  TotalMenOlder60  TotalPopulation  \
# 0            5767             1614            21378
# 1           30061            14724           129690
# 2           17115             8356            69909
# 3           12668             9036            58268
# 4           10619             6444            49248
#
#    TotalPopulationOfRetirementAge  TotalPopulationUnder18  \
# 0                            6399                    3436
# 1                           52460                   18193
# ...

# %% [markdown]
# **TotalPopulation** - all population
#
# **TotalWomen** - total number of women
#
# **TotalMen** - total number of men
#
# **TotalPopulationUnder18** - total number of population under 18
#
# **TotalMen18to27** - total number of men from 18 to 27 years old
#
# **TotalPopulationWorkingAge** - number of people of working age
#
# **TotalWomen18to55** - number of women from 18 to 55 years old
#
# **TotalMen18to60** - number of men from 18 to 60 years old
#
# **TotalPopulationOfRetirementAge** - number of retired persons
#
# **TotalWomenOlder55** - number of women older than 55
#
# **TotalMenOlder60** - number of men older than 60
#
# **District** - Name of district
#
# **Area** - administrative boundary
#
# **buildings_count** - number of Khrushchevki in district

# %%
districts['buildings_count_normalized'] = districts['buildings_count']/districts['TotalPopulation']

# %% [markdown]
# ### Total population

# %%
base = districts.plot(column='TotalPopulation', linewidth=0.1, alpha=0.6, 
                      figsize=(12,10), cmap='Blues',scheme='Quantiles', legend=True);
base.set_axis_off()

# %%
features = ['TotalPopulation', 'TotalPopulationUnder18', 'TotalPopulationOfRetirementAge', 'TotalPopulationWorkingAge']
districts[features].hist(figsize=(18,10));

# %% [markdown]
# ### Khrushchevki on map

# %%
base = districts.plot(linewidth=0.1, facecolor=None, alpha=0.01, figsize=(12,10));
base.set_axis_off()
buildings.plot(column='year',ax=base, cmap='Blues', scheme='Quantiles',legend=True)

# %%
districts[['TotalPopulation','TotalPopulationOfRetirementAge', 'buildings_count']].corr()
# Out:
#                                 TotalPopulation  \
# TotalPopulation                        1.000000
# TotalPopulationOfRetirementAge         0.941424
# buildings_count                        0.203156
#
#                                 TotalPopulationOfRetirementAge  \
# TotalPopulation                                       0.941424
# TotalPopulationOfRetirementAge                        1.000000
# buildings_count                                       0.308078
#
#                                 buildings_count
# TotalPopulation                        0.203156
# TotalPopulationOfRetirementAge         0.308078
# buildings_count                        1.000000

# %%
base = districts.plot(column='buildings_count_normalized', linewidth=0.1, alpha=0.6, 
                      figsize=(12,10), cmap='Blues',scheme='Quantiles', legend=True);
base.set_axis_off()
